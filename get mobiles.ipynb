# %%
from numpy.core.numeric import NaN
from pandas import read_excel

# %%
data = read_excel("data.xlsx", sheet_name=0, na_values='n/a')
# print(data)
# print(data.keys())
# print(data['brand'])

# %%
# All Data Columns Names
data.keys()
# Out:
# Index(['id', 'user', 'brand', 'product', 'date_rev', 'date_buy', 'pros',
#        'cons', 'rate', 'rate1', 'rate2', 'rate3', 'rate4', 'rate5', 'rate6',
#        'shown', 'brand_pros', 'brand_cons', 'brand_rate', 'id.1', 'uname',
#        'email', 'uavatar', 'youtube', 'approved', 'twitter', 'facebook'],
#       dtype='object')

# %%
# All Mobiles Brands
set(data['brand'])
# Out:
# {'Apple',
#  'Asus',
#  'Condor',
#  'Gionee',
#  'HTC',
#  'Huawei',
#  'Infinix',
#  'LGE',
#  'Leeco',
#  'Lenovo',
#  'Leotec',
#  'Meizu',
#  'Motorola',
#  'Nokia',
#  'OnePlus',
#  'Oppo',
#  'Samsung',
#  'Sony',
#  'TCT (Alcatel)',
#  'Tecno',
#  'Xiaomi'}

# %%
# All Mobiles Names
set(data['brand'] + " " + data['product'])
# Out:
# {'Apple iPhone',
#  'Apple iPhone 4s',
#  'Apple iPhone 5s',
#  'Apple iPhone 6',
#  'Apple iPhone 6 Plus',
#  'Apple iPhone 6s',
#  'Apple iPhone 6s Plus',
#  'Apple iPhone 7',
#  'Apple iPhone 7 Plus',
#  'Apple iPhone 8',
#  'Apple iPhone 8 Plus',
#  'Apple iPhone SE',
#  'Apple iPhone X',
#  'Apple iPhone XR',
#  'Apple iPhone XS Max',
#  'Asus ZenFone Go (ZB551KL)',
#  'Asus ZenFone Max (ZC550KL)',
#  'Asus ZenFone Selfie (ZD551KL)',
#  'Condor Infinity E5',
#  'Gionee A1 Lite',
#  'HTC Desire 628 dual sim',
#  'HTC Desire 630 dual sim',
#  'HTC Desire 820 dual sim',
#  'HTC Desire 820G PLUS dual sim',
#  'HTC One X9',
#  'HTC U Play',
#  'Huawei GR3',
#  'Huawei GR3 2017',
#  'Huawei GR5',
#  'Huawei GR5 2017',
#  'Huawei GT3',
#  'Huawei HONOR 20',
#  'Huawei HONOR 20 Pro',
#  'Huawei HONOR 20 lite',
#  'Huawei HONOR 4X',
#  'Huawei HONOR 8S',
#  'Huawei HONOR View 20',
#  'Huawei Honor 10',
#  'Huawei Honor 10 Lite',
#  'Huawei Honor 5X',
#  'Huawei Honor 6X',
# ...

# %%
# All Positive Reviews
data['pros']
# data['pros'][0]
# Out:
# 0       مرن وسهل الاستخدام ومليئ بالمزايا التي تسهل عل...
# 1                        كل شيء الجهاز ممتاز ما شاء الله
# 2                                 Its shape and its Color
# 3       نسخة ال64/4 الاداء جبار  مساحة و رام كويس جدا ...
# 4       الكاميرا كويسة نوعا ما وسعره برضو مش غالي اوي ...
#                               ...
# 1169                     مواصفاته كويسة جدا بالنسبة لسعره
# 1170    الموبايل كويس جدا لحد دلوقتي  عاجبني شكل البصم...
# 1171                                    دقة الشاشة كويسة
# 1172    البطارية محترمة شاشة كبيرة الرامات كويسة بيشحن...
# 1173                        تصميم رائع و معالجة صور رائعة
# Name: pros, Length: 1174, dtype: object

# %%
data.head(1)
# Out:
#    id                          user  brand product    date_rev    date_buy  \
# 0   1  tYCHUoxpDZTVIYuKtrZwVcqkqni2  Apple  iPhone  2019-06-28  2018-09-01
#
#                                                 pros  \
# 0  مرن وسهل الاستخدام ومليئ بالمزايا التي تسهل عل...
#
#                                                 cons  rate  rate1  ...  \
# 0  الشاشة سهلة الكسر وغالية جدا وأيضا ذاكرة الصور...     1      5  ...
#
#                                           brand_cons  brand_rate  \
# 0  الشاشة سهلة الكسر وغالية جدا وسعة الهاتف للصور...           4
#
#                            id.1         uname  email  uavatar youtube  \
# 0  tYCHUoxpDZTVIYuKtrZwVcqkqni2  Ghada Mohsen    NaN      NaN     NaN
#
#   approved  twitter facebook
# 0        0      NaN      NaN
#
# [1 rows x 27 columns]

# %%
data.iloc[0, :]
# Out:
# id                                                            1
# user                               tYCHUoxpDZTVIYuKtrZwVcqkqni2
# brand                                                     Apple
# product                                                  iPhone
# date_rev                                             2019-06-28
# date_buy                                             2018-09-01
# pros          مرن وسهل الاستخدام ومليئ بالمزايا التي تسهل عل...
# cons          الشاشة سهلة الكسر وغالية جدا وأيضا ذاكرة الصور...
# rate                                                          1
# rate1                                                         5
# rate2                                                         5
# rate3                                                         4
# rate4                                                         4
# rate5                                                         5
# rate6                                                         4
# ...

# %%
# All Saved users
set(data['uname'])
# Out:
# {'3bood2016',
#  'ABC 77',
#  'AHMAD',
#  'ASHRAF MOHAMED',
#  'Abanoub',
#  'Abd El Rahman Gamil',
#  'Abd El Rahman M. El Askary',
#  'Abd El-Rahman M. El-Newahy',
#  'Abd El-Rahman Mohamed',
#  'Abd Elrhman Karawia',
#  'Abdalla Mario',
#  'Abdallah Adel',
#  'Abdallah Mohamed Soliman',
#  'Abdallah Sameh',
#  'Abdallah nabil',
#  'Abdel Ali Ait Laarej',
#  'Abdel Rahman Mohamed',
#  'Abdel-Rahman Megahed',
#  'Abdelkader Ashraf',
#  'Abdelmonem Adel',
#  'Abdelrafe Sharab',
#  'Abdelrahman',
#  'Abdelrahman Ahmed',
#  'Abdelrahman Elkollaly',
#  'Abdelrahman Hanafy',
#  'Abdelrahman Ibrahim',
#  'Abdelrahman Rabie',
#  'Abdelrahman Ramadan',
#  'Abdelrahman Safie',
#  'Abdelrahman Soliman',
#  'Abdelrhman Hany',
#  'Abdelrhman Mohamed Gaber',
#  'Abdelrhman Qumhawy',
#  'Abdelrhman Tarek',
#  'Abdelrhman mohamed zaki',
#  'Abdelwahab Mmdouh',
#  'Abdo Ahmed',
#  'Abdo Altorky',
#  'Abdo Karbal',
#  'Abdo Mohammed',
#  'Abdou Zyada',
#  'Abdul Rahman Kassab',
# ...
